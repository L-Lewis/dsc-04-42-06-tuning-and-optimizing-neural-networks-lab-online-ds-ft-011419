# %% [markdown]
# # Tuning and Optimizing Neural Networks - Lab
#
# ## Introduction
#
# Now that we've discussed some regularization, initialization and optimization techniques, its time to synthesize those concepts into a cohesive modelling pipeline.
#
# With this pipeline, you will not only fit an initial model but will also attempt to set various hyperparameters for regularization techniques. Your final model selection will pertain to the test metrics across these models. This will more naturally simulate a problem you might be faced with in practice, and the various modelling decisions you are apt to encounter along the way.
#
# Recall that our end objective is to achieve a balance between overfitting and underfitting. We've discussed the bias variance tradeoff, and the role of regularization in order to reduce overfitting on training data and improving generalization to new cases. Common frameworks for such a procedure include train/validate/test methodology when data is plentiful, and K-folds cross-validation for smaller, more limited datasets. In this lab, you'll perform the latter, as the dataset in question is fairly limited.
#
# ## Objectives
#
# You will be able to:
#
# * Implement a K-folds cross validation modelling pipeline
# * Apply normalization as a preprocessing technique
# * Apply regularization techniques to improve your model's generalization
# * Choose an appropriate optimization strategy

# %% [markdown]
# ## Loading the Data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from keras import models, layers, optimizers, regularizers
import time
import datetime

# %%
#Your code here; load and preview the dataset
df = pd.read_csv('loan_final.csv')
print(len(df))
df.head()
# Out:
# 42538
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   emp_length home_ownership  annual_inc verification_status  loan_status  \
# 0  10+ years           RENT     24000.0            Verified   Fully Paid
# 1   < 1 year           RENT     30000.0     Source Verified  Charged Off
# 2  10+ years           RENT     12252.0        Not Verified   Fully Paid
# 3  10+ years           RENT     49200.0     Source Verified   Fully Paid
# 4     1 year           RENT     80000.0     Source Verified   Fully Paid
#
#           purpose addr_state  total_acc   total_pymnt application_type
# 0     credit_card         AZ        9.0   5863.155187       Individual
# 1             car         GA        4.0   1014.530000       Individual
# 2  small_business         IL       10.0   3005.666844       Individual
# 3           other         CA       37.0  12231.890000       Individual
# 4           other         OR       38.0   4066.908161       Individual

# %% [markdown]
# ## Defining the Problem
#
# Set up the problem by defining X and Y.
#
# For this problem use the following variables for X:
# * loan_amnt
# * home_ownership
# * funded_amnt_inv
# * verification_status
# * emp_length
# * installment
# * annual_inc
#
# Be sure to use dummy variables for categorical variables and to normalize numerical quanitities. Be sure to also remove any rows with null data.
#
# For Y, we are looking to build a model to predict the total payment received for a loan.

# %%
# Your code here; appropriately define X and Y using dummy variables and normalization for preprocessing.
df.dropna(inplace=True)

# %%
# My version - doesn't work as fit_transformed columns need reshaping
#sc = StandardScaler()
#X1 = pd.DataFrame(sc.fit_transform([df.loan_amnt]))
#X2 = pd.get_dummies(df.home_ownership)
#X3 = pd.DataFrame(sc.fit_transform([df.funded_amnt_inv]))
#X4 = pd.get_dummies(df.verification_status)
#X5 = pd.get_dummies(df.emp_length)
#X6 = pd.DataFrame(sc.fit_transform([df.installment]))
#X7 = pd.DataFrame(sc.fit_transform([df.annual_inc]))

#X = pd.concat([X1, X2, X3, X4, X5, X6, X7], axis=1)

#Y = df.total_pymnt

# %%
data = df
# From solutions to save time

X0 = data["loan_amnt"]
X1 = data["funded_amnt_inv"]
X2 = data["installment"]
X3 = data["annual_inc"]

# standardized inputs
X0= (X0-np.mean(X0))/(np.std(X0))
X1= (X1-np.mean(X1))/(np.std(X1))
X2= (X2-np.mean(X2))/(np.std(X2))
X3= (X3-np.mean(X3))/(np.std(X3))

#SAME RESULT (apparently...)

#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X0 = sc.fit_transform(X0)

dummy_ver = pd.get_dummies(data['verification_status'])
dummy_home = pd.get_dummies(data['home_ownership'])
dummy_emp = pd.get_dummies(data['emp_length'])

X = pd.concat([X0, X1, X2, X3, dummy_ver, dummy_home, dummy_emp], axis=1)
X = X.dropna()
y = data["total_pymnt"]
y = (y-np.mean(y))/np.std(y)

print(np.shape(X))
# Out:
# (41394, 23)

# %% [markdown]
# ## Generating a Hold Out Test Set
#
# While we will be using K-fold cross validation to select an optimal model, we still want a final hold out test set that is completely independent of any modelling decisions. As such, pull out a sample of 10% of the total available data. For consistency of results, use random seed 123.

# %%
# Your code here; generate a hold out test set for final model evaluation. Use random seed 123.
np.random.seed(123)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# ## Defining a K-fold Cross Validation Methodology
#
# Now that your have a complete holdout test set, write a function that takes in the remaining data and performs k-folds cross validation given a model object. Be sure your function returns performance metrics regarding the training and validation sets.

# %%
# Your code here; define a function to evaluate a model object using K folds cross validation.
# From solutions

def k_folds(features_train, labels_train, model_obj, k=10, n_epochs=100):
    colors = sns.color_palette("Set2")

    validation_scores = [] 
    
    kf = KFold(n_splits=10, shuffle=True)
    
    fig, axes = plt.subplots(2, 5, figsize=(12,8))
    for i, (train_index, test_index) in enumerate(kf.split(features_train)):
        "Currently graph imaging assumes 10 folds and is hardcoded to 5x2 layout."
        row = i//5
        col = i%5
        X_train, X_val = features_train.iloc[train_index], features_train.iloc[test_index]
        y_train, y_val = labels_train.iloc[train_index], labels_train.iloc[test_index]
        
        model = model_obj
        hist = model.fit(X_train, y_train, batch_size=32,
                         epochs=n_epochs, verbose=0, validation_data = (X_val, y_val))
        #Note: verbose=0 turns off printouts regarding training for each epoch.
        #Potential simpler methodology
        validation_score = model.evaluate(X_val, y_val)
        validation_scores.append(validation_score)
        ax = axes[row, col]
        k = 'val_loss'
        d = hist.history[k]
        ax.plot(d, label=k, color=colors[0])

        k = 'loss'
        d = hist.history[k]
        ax.plot(d, label=k, color=colors[1])
        ax.set_title('Fold {} Validation'.format(i+1))
    #Final Graph Formatting
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.5, hspace=None)
    plt.legend(bbox_to_anchor=(1,1))
    
    #General Overview
    validation_score = np.average(validation_scores)
    print('Mean Validation Score:', validation_score)
    print('Standard Deviation of Validation Scores:', np.std(validation_scores))
    return validation_score

# %% [markdown]
# ## Building a Baseline Model
#
# Here, it is also important to define your evaluation metric that you will look to optimize while tuning the model.
#
# In general, model training to optimize this metric may consist of using a validation and test set if data is plentiful, or k-folds cross-validation if data is limited. We set up a k-folds cross-validation for this task since the dataset is not overly large.
#
# Build an initial sequential model with 2 hidden relu layers. The first should have 7 hidden units, and the second 10 hidden units. Finally, add a third layer with a linear activation function to output our predictions for the total loan payment.

# %%
#Your code here; define and compile an initial model as described
model = models.Sequential()
model.add(layers.Dense(7, input_dim=23, kernel_initializer='normal', activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='linear'))

# %%
model.compile(optimizer='SGD',
              loss='mse',
              metrics=['mse'])

# %% [markdown]
# ## Evaluating the Baseline Model with K-Folds Cross Validation
#
# Use your k-folds function to evaluate the baseline model.
#
# Note: This code block is likely to take 10-20 minutes to run depending on the specs on your computer.
# Because of time dependencies, it can be interesting to begin timing these operations for future reference.
#
# Here's a simple little recipe to achieve this:
# ```
# import time
# import datetime
#
# now = datetime.datetime.now()
# later = datetime.datetime.now()
# elapsed = later - now
# print('Time Elapsed:', elapsed)
# ```

# %%
#Your code here; use your k-folds function to evaluate the baseline model.
now = datetime.datetime.now()
k_folds(X_train, y_train, model)
later = datetime.datetime.now()
elapsed = later - now
print("Time elapsed:", elapsed)
# Out:
# 3726/3726 [==============================] - 0s 17us/step
# 3726/3726 [==============================] - 0s 20us/step
# 3726/3726 [==============================] - 0s 16us/step
# 3726/3726 [==============================] - 0s 16us/step
# 3725/3725 [==============================] - 0s 21us/step
# 3725/3725 [==============================] - 0s 13us/step
# 3725/3725 [==============================] - 0s 13us/step
# 3725/3725 [==============================] - 0s 18us/step
# 3725/3725 [==============================] - 0s 13us/step
# 3725/3725 [==============================] - 0s 16us/step
# Mean Validation Score: 0.18570163095760975
# Standard Deviation of Validation Scores: 0.014850214309496358
# Time elapsed: 0:14:25.031506

# %% [markdown]
# ## Intentionally Overfitting a Model
#
# Now that you've developed a baseline model, its time to intentionally overfit a model. To overfit a model, you can:
# * Add layers
# * Make the layers bigger
# * Increase the number of training epochs
#
# Again, be careful here. Think about the limitations of your resources, both in terms of your computers specs and how much time and patience you have to let the process run. Also keep in mind that you will then be regularizing these overfit models, meaning another round of experiments and more time and resources.
#
# For example, here are some timing notes on potential experiments run on a Macbook Pro 3.1 GHz Intel Core i5 with 16gb of RAM:
#
# * Using our 10 fold cross validation methodology, a 5-layer neural network with 10 units per hidden layer and 100 epochs took approximately 15 minutes to train and validate
#
# * Using our 10 fold cross validation methodology, a 5-layer neural network with 25 units per hidden layer and 100 epochs took approximately 25 minutes to train and validate
#
# * Using our 10 fold cross validation methodology, a 5-layer neural network with 10 units per hidden layer and 250 epochs took approximately 45 minutes to train and validate

# %%
#Your code here; try some methods to overfit your network
# See solutions - not run due to lack of time

# %%
#Your code here; try some methods to overfit your network

# %%
#Your code here; try some methods to overfit your network

# %% [markdown]
# ## Regularizing the Model to Achieve Balance
#
# Now that you have a powerful model (albeit an overfit one), we can now increase the generalization of the model by using some of the regularization techniques we discussed. Some options you have to try include:
# * Adding dropout
# * Adding L1/L2 regularization
# * Altering the layer architecture (add or remove layers similar to above)
#
# This process will be constrained by time and resources. Be sure to test at least 2 different methodologies, such as dropout and L2 regularization. If you have the time, feel free to continue experimenting.
#
# Notes:

# %%
#Your code here; try some regularization or other methods to tune your network
# Dropout regularization
model = models.Sequential()
model.add(layers.Dense(7, input_dim=23, kernel_initializer='normal', activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='linear'))

model.compile(optimizer='SGD', loss='mse', metrics=['mse'])

now = datetime.datetime.now()
k_folds(X_train, y_train, model)
later = datetime.datetime.now()
elapsed = later - now
print("Time elapsed:", elapsed)
# Out:
# 3726/3726 [==============================] - 0s 26us/step
# 3726/3726 [==============================] - 0s 20us/step
# 3726/3726 [==============================] - 0s 19us/step
# 3726/3726 [==============================] - 0s 20us/step
# 3725/3725 [==============================] - 0s 20us/step
# 3725/3725 [==============================] - 0s 20us/step
# 3725/3725 [==============================] - 0s 20us/step
# 3725/3725 [==============================] - 0s 19us/step
# 3725/3725 [==============================] - 0s 25us/step
# 3725/3725 [==============================] - 0s 20us/step
# Mean Validation Score: 0.2733785449919461
# Standard Deviation of Validation Scores: 0.024466193378519685
# Time elapsed: 0:15:09.502548

# %%
#Your code here; try some regularization or other methods to tune your network
# L1 regularization and early stopping
model = models.Sequential()
model.add(layers.Dense(7, kernel_regularizer=regularizers.l1(0.005), input_dim=23, kernel_initializer='normal', activation='relu'))
model.add(layers.Dense(10, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
model.add(layers.Dense(1, activation='linear'))

model.compile(optimizer='SGD', loss='mse', metrics=['mse'])

now = datetime.datetime.now()
k_folds(X_train, y_train, model, n_epochs=50)
later = datetime.datetime.now()
elapsed = later - now
print("Time elapsed:", elapsed)
# Out:
# 3726/3726 [==============================] - 0s 18us/step
# 3726/3726 [==============================] - 0s 18us/step
# 3726/3726 [==============================] - 0s 14us/step
# 3726/3726 [==============================] - 0s 19us/step
# 3725/3725 [==============================] - 0s 14us/step
# 3725/3725 [==============================] - 0s 19us/step
# 3725/3725 [==============================] - 0s 20us/step
# 3725/3725 [==============================] - 0s 17us/step
# 3725/3725 [==============================] - 0s 32us/step
# 3725/3725 [==============================] - 0s 14us/step
# Mean Validation Score: 0.19906598618269786
# Standard Deviation of Validation Scores: 0.01416345836591864
# Time elapsed: 0:07:21.379253

# %%
#Your code here; try some regularization or other methods to tune your network

# %%
#Your code here; try some regularization or other methods to tune your network

# %% [markdown]
# ## Final Evaluation
#
# Now that you have selected a network architecture, tested various regularization procedures and tuned hyperparameters via a validation methodology, it is time to evaluate your finalized model once and for all. Fit the model using all of the training and validation data using the architecture and hyperparameters that were most effective in your expirements above. Afterwards, measure the overall performance on the hold-out test data which has been left untouched (and hasn't leaked any data into the modelling process)!

# %%
#Your code here; final model training on entire training set followed by evaluation on hold-out data
# Dropout regularization
now = datetime.datetime.now()

model = models.Sequential()
model.add(layers.Dense(7, input_dim=23, kernel_initializer='normal', activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='linear'))

model.compile(optimizer='SGD', loss='mse', metrics=['mse'])
history = model.fit(X_train, y_train, batch_size=32, epochs=100)

later = datetime.datetime.now()
elapsed = later - now
print("Time elapsed:", elapsed)
# Out:
# Epoch 1/100
# 37254/37254 [==============================] - 1s 39us/step - loss: 0.4656 - mean_squared_error: 0.4656
# Epoch 2/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3668 - mean_squared_error: 0.3668
# Epoch 3/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3440 - mean_squared_error: 0.3440
# Epoch 4/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3419 - mean_squared_error: 0.3419
# Epoch 5/100
# 37254/37254 [==============================] - 1s 38us/step - loss: 0.3375 - mean_squared_error: 0.3375
# Epoch 6/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3369 - mean_squared_error: 0.3369
# Epoch 7/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3366 - mean_squared_error: 0.3366
# Epoch 8/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3291 - mean_squared_error: 0.3291
# Epoch 9/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3328 - mean_squared_error: 0.3328
# Epoch 10/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3297 - mean_squared_error: 0.3297
# Epoch 11/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3346 - mean_squared_error: 0.3346
# Epoch 12/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3261 - mean_squared_error: 0.3261
# Epoch 13/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3236 - mean_squared_error: 0.3236
# Epoch 14/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3272 - mean_squared_error: 0.3272
# Epoch 15/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3295 - mean_squared_error: 0.3295
# Epoch 16/100
# 37254/37254 [==============================] - 1s 34us/step - loss: 0.3298 - mean_squared_error: 0.3298
# Epoch 17/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3252 - mean_squared_error: 0.3252
# Epoch 18/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3208 - mean_squared_error: 0.3208
# Epoch 19/100
# 37254/37254 [==============================] - 1s 34us/step - loss: 0.3227 - mean_squared_error: 0.3227
# Epoch 20/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3237 - mean_squared_error: 0.3237
# Epoch 21/100
# 37254/37254 [==============================] - 1s 37us/step - loss: 0.3214 - mean_squared_error: 0.3214
# Epoch 22/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3291 - mean_squared_error: 0.3291
# Epoch 23/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3283 - mean_squared_error: 0.3283
# Epoch 24/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3275 - mean_squared_error: 0.3275
# Epoch 25/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3234 - mean_squared_error: 0.3234
# Epoch 26/100
# 37254/37254 [==============================] - 1s 34us/step - loss: 0.3235 - mean_squared_error: 0.3235
# Epoch 27/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3278 - mean_squared_error: 0.3278
# Epoch 28/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3219 - mean_squared_error: 0.3219
# Epoch 29/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3309 - mean_squared_error: 0.3309
# Epoch 30/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3289 - mean_squared_error: 0.3289
# Epoch 31/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3269 - mean_squared_error: 0.3269
# Epoch 32/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3257 - mean_squared_error: 0.3257
# Epoch 33/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3194 - mean_squared_error: 0.3194
# Epoch 34/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3265 - mean_squared_error: 0.3265
# Epoch 35/100
# 37254/37254 [==============================] - 1s 34us/step - loss: 0.3206 - mean_squared_error: 0.3206
# Epoch 36/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3205 - mean_squared_error: 0.3205
# Epoch 37/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3286 - mean_squared_error: 0.3286
# Epoch 38/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3209 - mean_squared_error: 0.3209
# Epoch 39/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3239 - mean_squared_error: 0.3239
# Epoch 40/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3186 - mean_squared_error: 0.3186 1s - l
# Epoch 41/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3218 - mean_squared_error: 0.3218
# Epoch 42/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3216 - mean_squared_error: 0.3216
# Epoch 43/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3298 - mean_squared_error: 0.3298
# Epoch 44/100
# 37254/37254 [==============================] - 2s 46us/step - loss: 0.3240 - mean_squared_error: 0.3240
# Epoch 45/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3241 - mean_squared_error: 0.3241
# Epoch 46/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3279 - mean_squared_error: 0.3279
# Epoch 47/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3277 - mean_squared_error: 0.3277
# Epoch 48/100
# 37254/37254 [==============================] - 1s 38us/step - loss: 0.3292 - mean_squared_error: 0.3292
# Epoch 49/100
# 37254/37254 [==============================] - 2s 45us/step - loss: 0.3240 - mean_squared_error: 0.3240
# Epoch 50/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3270 - mean_squared_error: 0.3270
# Epoch 51/100
# 37254/37254 [==============================] - 1s 29us/step - loss: 0.3182 - mean_squared_error: 0.3182
# Epoch 52/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3232 - mean_squared_error: 0.3232
# Epoch 53/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3229 - mean_squared_error: 0.3229
# Epoch 54/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3177 - mean_squared_error: 0.3177
# Epoch 55/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3205 - mean_squared_error: 0.3205
# Epoch 56/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3235 - mean_squared_error: 0.3235
# Epoch 57/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3259 - mean_squared_error: 0.3259
# Epoch 58/100
# 37254/37254 [==============================] - 1s 29us/step - loss: 0.3206 - mean_squared_error: 0.3206
# Epoch 59/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3234 - mean_squared_error: 0.3234
# Epoch 60/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3200 - mean_squared_error: 0.3200
# Epoch 61/100
# 37254/37254 [==============================] - 2s 54us/step - loss: 0.3157 - mean_squared_error: 0.3157
# Epoch 62/100
# 37254/37254 [==============================] - 2s 51us/step - loss: 0.3222 - mean_squared_error: 0.3222
# Epoch 63/100
# 37254/37254 [==============================] - 3s 70us/step - loss: 0.3284 - mean_squared_error: 0.3284
# Epoch 64/100
# 37254/37254 [==============================] - 3s 71us/step - loss: 0.3289 - mean_squared_error: 0.3289
# Epoch 65/100
# 37254/37254 [==============================] - 3s 69us/step - loss: 0.3230 - mean_squared_error: 0.3230
# Epoch 66/100
# 37254/37254 [==============================] - 3s 71us/step - loss: 0.3176 - mean_squared_error: 0.3176
# Epoch 67/100
# 37254/37254 [==============================] - 2s 44us/step - loss: 0.3299 - mean_squared_error: 0.3299
# Epoch 68/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3180 - mean_squared_error: 0.3180
# Epoch 69/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3165 - mean_squared_error: 0.3165
# Epoch 70/100
# 37254/37254 [==============================] - 1s 29us/step - loss: 0.3278 - mean_squared_error: 0.3278
# Epoch 71/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3271 - mean_squared_error: 0.3271
# Epoch 72/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3347 - mean_squared_error: 0.3347
# Epoch 73/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3223 - mean_squared_error: 0.3223
# Epoch 74/100
# 37254/37254 [==============================] - 2s 42us/step - loss: 0.3195 - mean_squared_error: 0.3195
# Epoch 75/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3196 - mean_squared_error: 0.3196
# Epoch 76/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3240 - mean_squared_error: 0.3240
# Epoch 77/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3238 - mean_squared_error: 0.3238
# Epoch 78/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3207 - mean_squared_error: 0.3207
# Epoch 79/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3167 - mean_squared_error: 0.3167
# Epoch 80/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3165 - mean_squared_error: 0.3165
# Epoch 81/100
# 37254/37254 [==============================] - 1s 37us/step - loss: 0.3228 - mean_squared_error: 0.3228
# Epoch 82/100
# 37254/37254 [==============================] - 2s 48us/step - loss: 0.3245 - mean_squared_error: 0.3245
# Epoch 83/100
# 37254/37254 [==============================] - 1s 33us/step - loss: 0.3208 - mean_squared_error: 0.3208
# Epoch 84/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3218 - mean_squared_error: 0.3218
# Epoch 85/100
# 37254/37254 [==============================] - 1s 29us/step - loss: 0.3250 - mean_squared_error: 0.3250
# Epoch 86/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3180 - mean_squared_error: 0.3180
# Epoch 87/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3262 - mean_squared_error: 0.3262
# Epoch 88/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3171 - mean_squared_error: 0.3171
# Epoch 89/100
# 37254/37254 [==============================] - 1s 32us/step - loss: 0.3247 - mean_squared_error: 0.3247
# Epoch 90/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3253 - mean_squared_error: 0.3253
# Epoch 91/100
# 37254/37254 [==============================] - 1s 27us/step - loss: 0.3118 - mean_squared_error: 0.3118
# Epoch 92/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3201 - mean_squared_error: 0.3201
# Epoch 93/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3193 - mean_squared_error: 0.3193
# Epoch 94/100
# 37254/37254 [==============================] - 1s 31us/step - loss: 0.3220 - mean_squared_error: 0.3220
# Epoch 95/100
# 37254/37254 [==============================] - 1s 35us/step - loss: 0.3213 - mean_squared_error: 0.3213
# Epoch 96/100
# 37254/37254 [==============================] - 1s 29us/step - loss: 0.3189 - mean_squared_error: 0.3189
# Epoch 97/100
# 37254/37254 [==============================] - 1s 30us/step - loss: 0.3283 - mean_squared_error: 0.3283
# Epoch 98/100
# 37254/37254 [==============================] - 1s 36us/step - loss: 0.3282 - mean_squared_error: 0.3282
# Epoch 99/100
# 37254/37254 [==============================] - 2s 43us/step - loss: 0.3214 - mean_squared_error: 0.3214
# Epoch 100/100
# 37254/37254 [==============================] - 1s 28us/step - loss: 0.3248 - mean_squared_error: 0.3248
# Time elapsed: 0:02:10.154830

# %%
model.evaluate(X_test, y_test)
# Out:
# 4140/4140 [==============================] - 0s 27us/step
# [0.271499332540853, 0.271499332540853]

# %% [markdown]
# ## Additional Resources

# %% [markdown]
# https://machinelearningmastery.com/dropout-regularization-deep-learning-models-keras/
#
# https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/
#
# https://machinelearningmastery.com/regression-tutorial-keras-deep-learning-library-python/
#
# https://stackoverflow.com/questions/37232782/nan-loss-when-training-regression-network
# https://www.springboard.com/blog/free-public-data-sets-data-science-project/

# %% [markdown]
# ## Summary
#
# In this lab, we investigated some data from *The Lending Club* in a complete data science pipeline regarding neural networks. We began with reserving a hold-out set for testing which never was touched during the modeling phase. From there, we implemented a k-fold cross validation methodology in order to assess an initial baseline model and various regularization methods. From here, we'll begin to investigate other neural network architectures such as CNNs.
